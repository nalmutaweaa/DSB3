# %%
import pandas as pd
plant = pd.read_csv('plants.csv')
print(plant.head())
# Out:
#         name location       date  water_freq sunlight     activity
# 0  sunflower   garden  16/9/2026           1     high     watering
# 1   petunia   balcony  10/9/2026           2   medium  fertilizing
